# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore") #用于排除警告
from sklearn.decomposition import PCA #主成分降维
from sklearn.preprocessing import StandardScaler #数据标准化
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
# 1获取数据
name=['Sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight'
      ,'Rings']
print(name)
df = pd.read_csv("./data/abalone.data",header=None,names=name)
display(df.tail(3))
data=df
# Out:
# ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4174          0.2875         0.308      9
# 4175          0.2610         0.296     10
# 4176          0.3765         0.495     12

# %%
data['Rings'].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24], dtype=int64)

# %%
import math
def plot_distribution(dataset, cols, width, height, hspace, wspace):
    fig = plt.figure(figsize = (width, height))
    fig.subplots_adjust(left=None,bottom=None,right=None,top=None,wspace=wspace,hspace=hspace)
    rows = math.ceil(dataset.shape[1] / cols)
    for i,column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i+1)
        ax.set_title(column)
        if dataset.dtypes[column] == np.object:
            g = sns.countplot(y=column, data=dataset)
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels = substrings)
            plt.xticks(rotation = 25)
        else:
            g = sns.distplot(dataset[column])
            plt.xticks(rotation = 25)
    plt.tight_layout()
plot_distribution(data, cols=3, width=24, height=20, hspace=0.2, wspace=0.5)

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# 改Sex列的值
data.loc[data['Sex']=='M','Sex'] = 0
data.loc[data['Sex']=='F','Sex'] = 1
data.loc[data['Sex']=='I','Sex'] = 2
# 改Sex列的数据类型，否则corr会不计算该列
data['Sex']=data['Sex'].astype(np.int)

transfer0 = StandardScaler() #实例化一个转换器类
xi = transfer0.fit_transform(data) #调用fit_transform()
data2 = pd.DataFrame(xi,columns=data.columns)

# %%
# 查找关联度
corr_matrix = data2.corr()
print(corr_matrix['Rings'].sort_values(ascending=False))
# 展示各特征之间的相关性
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True, vmax=1, square=True, cmap='Blues')
plt.show()
# Out:
# Rings             1.000000
# Shell weight      0.627574
# Diameter          0.574660
# Height            0.557467
# Length            0.556720
# Whole weight      0.540390
# Viscera weight    0.503819
# Shucked weight    0.420884
# Sex              -0.351822
# Name: Rings, dtype: float64

# %%
corr_matrix
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.448765 -0.458245 -0.417928     -0.461238
# Length         -0.448765  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.458245  0.986812  1.000000  0.833684      0.925452
# Height         -0.417928  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.461238  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.440927  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.454658  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.445549  0.897706  0.905330  0.817338      0.955355
# Rings          -0.351822  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.440927       -0.454658     -0.445549 -0.351822
# Length                0.897914        0.903018      0.897706  0.556720
# Diameter              0.893162        0.899724      0.905330  0.574660
# Height                0.774972        0.798319      0.817338  0.557467
# Whole weight          0.969405        0.966375      0.955355  0.540390
# Shucked weight        1.000000        0.931961      0.882617  0.420884
# Viscera weight        0.931961        1.000000      0.907656  0.503819
# Shell weight          0.882617        0.907656      1.000000  0.627574
# Rings                 0.420884        0.503819      0.627574  1.000000

# %%
X=data.drop('Sex',axis=1).values

# %%
X
# Out:
# array([[ 0.455 ,  0.365 ,  0.095 , ...,  0.101 ,  0.15  , 15.    ],
#        [ 0.35  ,  0.265 ,  0.09  , ...,  0.0485,  0.07  ,  7.    ],
#        [ 0.53  ,  0.42  ,  0.135 , ...,  0.1415,  0.21  ,  9.    ],
#        ...,
#        [ 0.6   ,  0.475 ,  0.205 , ...,  0.2875,  0.308 ,  9.    ],
#        [ 0.625 ,  0.485 ,  0.15  , ...,  0.261 ,  0.296 , 10.    ],
#        [ 0.71  ,  0.555 ,  0.195 , ...,  0.3765,  0.495 , 12.    ]])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
y_kmeans=kmeans.fit_predict(data.values)
plt.scatter(data.values[:, 0], data.values[:,8], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:,4], centers[:, 6], c='black', s=80, marker='x')

# %%
label=df.iloc[:,0].unique()

# %%
label
# Out:
# array([0, 1, 2])

# %%
Clu=KMeans(n_clusters=3,init='random',n_init=10,max_iter=300,random_state=0)
y_clu=Clu.fit_predict(X)
plt.scatter(X[y_clu==1,0],X[y_clu==1,3],s=50)

# %%
plt.scatter(X[:, 2], X[:,3], c=y_clu, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:,4], centers[:, 6], c='black', s=80, marker='x')

# %%
y_clu
# Out:
# array([0, 1, 1, ..., 1, 2, 2])

# %%
#来自sklearn.decomposition导入PCA
pca = PCA(n_components =3)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
principalDf
# Out:
#              0         1         2
# 0     5.004803 -0.866927  0.027876
# 1    -2.991062 -0.434572  0.041150
# 2    -0.946035 -0.086739 -0.063334
# 3     0.029437 -0.376935  0.004381
# 4    -2.994317 -0.466080  0.058218
# ...        ...       ...       ...
# 4172  1.069393 -0.023664 -0.039121
# 4173  0.082964  0.167178 -0.026324
# 4174 -0.888070  0.508786 -0.013685
# 4175  0.099892  0.340900 -0.041644
# 4176  2.184744  1.113787  0.098756
#
# [4177 rows x 3 columns]

# %%
a=principalDf.values

# %%
plt.figure(figsize = (40,10))
linewidth = 10
alpha = 0.3
from mpl_toolkits.mplot3d import Axes3D
ax = plt.subplot(1, 2, 1, projection='3d')
Clu=KMeans(n_clusters=37,init='random',n_init=10,max_iter=300,random_state=0)
y_clu=Clu.fit_predict(a)
plt.scatter(a[:,0],a[:,1],a[:,2],c=y_clu,linewidth=linewidth)

# %%
from sklearn.metrics import silhouette_score
sc_scores = []

clusters = [2,3,5,20,25,28,30,35,40,50]                                  #簇的个数
for t in clusters:
    Clu=KMeans(n_clusters=t,init='random',n_init=10,max_iter=300,random_state=0)
    y_clu=Clu.fit_predict(a)
    sc_score = silhouette_score(a, y_clu)
    sc_scores.append(sc_score)
plt.figure()
plt.plot(clusters, sc_scores, '*-')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficient Score')
# Out:
# Text(0, 0.5, 'Silhouette Coefficient Score')

# %%
from sklearn.metrics import silhouette_score
sc_scores = []

clusters = [2,3,5,20,25,28,30,35,40,50]                                  #簇的个数
for t in clusters:
    Clu=KMeans(n_clusters=t,init='random',n_init=10,max_iter=300,random_state=0)
    y_clu=Clu.fit_predict(data.values)
    sc_score = silhouette_score(data.values, y_clu)
    sc_scores.append(sc_score)
plt.figure()
plt.plot(clusters, sc_scores, '*-')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficient Score')
# Out:
# Text(0, 0.5, 'Silhouette Coefficient Score')

# %%
pca = PCA(n_components =2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
Clu=KMeans(n_clusters=3,init='random',n_init=10,max_iter=300,random_state=0)
model=Clu.fit(principalDf)
y_clu=model.predict(principalDf)
plt.scatter(principalDf.values[:,1],principalDf.values[:,0],c=y_clu,linewidth=linewidth)

# %%
b=data.iloc[:,1:9].sample(frac=0.1)
label=data.iloc[:,0]
b
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 731    0.545     0.420   0.130        0.8790          0.3740          0.1695
# 1891   0.565     0.435   0.145        0.8445          0.3975          0.1580
# 2885   0.505     0.400   0.125        0.5605          0.2255          0.1435
# 182    0.560     0.450   0.160        1.0235          0.4290          0.2680
# 176    0.315     0.210   0.060        0.1250          0.0600          0.0375
# ...      ...       ...     ...           ...             ...             ...
# 1948   0.635     0.515   0.165        1.2290          0.5055          0.2975
# 80     0.575     0.445   0.140        0.9410          0.3845          0.2520
# 1350   0.595     0.465   0.150        0.9800          0.4115          0.1960
# 1881   0.550     0.450   0.130        0.8040          0.3375          0.1405
# 3569   0.580     0.470   0.150        0.9070          0.4440          0.1855
#
#       Shell weight  Rings
# 731         0.2300     13
# 1891        0.2550      9
# 2885        0.1700      8
# 182         0.3000     10
# 176         0.0350      5
# ...            ...    ...
# 1948        0.3535     10
# 80          0.2850      9
# 1350        0.2255     10
# 1881        0.2300      6
# 3569        0.2445     11
#
# [418 rows x 8 columns]

# %%
from sklearn.metrics import silhouette_score
sc_scores = []
clusters = [2,3,5,20,25,28,30,35,40,50]                                  #簇的个数
for t in clusters:
    Clu=KMeans(n_clusters=t,init='random',n_init=10,max_iter=300,random_state=0)
    y_clu=Clu.fit_predict(b)
    sc_score = silhouette_score(b, y_clu)
    sc_scores.append(sc_score)
plt.figure()
plt.plot(clusters, sc_scores, '*-')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficient Score')
# Out:
# Text(0, 0.5, 'Silhouette Coefficient Score')

# %%
linewidth = 1
Clu=KMeans(n_clusters=20,init='random',n_init=10,max_iter=300,tol=0.0001,random_state=0)
model=Clu.fit(b.values)
y_clu=model.predict(b.values)
plt.scatter(b.values[:,0],b.values[:,1],c=y_clu,linewidth=linewidth)
centers = model.cluster_centers_
plt.scatter(centers[:,0], centers[:, 1], c='black',linewidth = 2, s=80, marker='o')

# %%
# plt.figure(figsize = (40,10))
b=data.iloc[:,1:3]
label=data.iloc[:,0]
b
Clu=KMeans(n_clusters=3,init='random',n_init=10,max_iter=300,tol=0.0001,random_state=0)
model=Clu.fit(b.values)
y_clu=model.predict(b.values)
plt.scatter(b.values[:,0],b.values[:,1],c=y_clu,linewidth=linewidth)
centers = model.cluster_centers_
plt.scatter(centers[:,0], centers[:, 1], c='black',linewidth = 2, s=80, marker='o')

# %%
sc_score = silhouette_score(b, y_clu)
sc_score
# Out:
# 0.5416207351247193

# %%
clusters = [2,3,5,20,25,28,30,35,40,50]  
sc_scores=[]
#簇的个数
for t in clusters:
    Clu=KMeans(n_clusters=t,init='random',n_init=10,max_iter=300,random_state=0)
    y_clu=Clu.fit_predict(b)
    sc_score = silhouette_score(b, y_clu)
    sc_scores.append(sc_score)
plt.figure()
plt.plot(clusters, sc_scores, '*-')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficient Score')
# Out:
# Text(0, 0.5, 'Silhouette Coefficient Score')

# %%
data
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       0   0.455     0.365   0.095        0.5140          0.2245
# 1       0   0.350     0.265   0.090        0.2255          0.0995
# 2       1   0.530     0.420   0.135        0.6770          0.2565
# 3       0   0.440     0.365   0.125        0.5160          0.2155
# 4       2   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    1   0.565     0.450   0.165        0.8870          0.3700
# 4173    0   0.590     0.440   0.135        0.9660          0.4390
# 4174    0   0.600     0.475   0.205        1.1760          0.5255
# 4175    1   0.625     0.485   0.150        1.0945          0.5310
# 4176    0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
import torch
torch.rand(1)
# Out:
# tensor([0.1749])

# %%
# 自定义函数
"""
复现聚类算法（加分项）numpy 或 torch 等 
（1）为每个聚类选择一个初始聚类中心；
（2）将样本集按照最小距离原则分配到最邻近聚类；
（3）使用每个聚类的样本均值更新聚类中心；
（4）重复步骤（2）、（3），直到聚类中心不再发生变化；
（5）输出最终的聚类中心和 k 个簇划分（作图）；
"""

# %%
import torch
class My_KMeans():
    def __init__(self, n_clusters=20, max_iter=1000, verbose=True):
        """
        @初始化
        @n_clusters
        @return
        """
        self.n_cluster = n_clusters
        self.n_clusters = n_clusters
        self.labels = None
        self.dists = None  # shape: [x.shape[0],n_cluster]
        self.centers = None
      #  self.variation = torch.Tensor([float("Inf")]).to(device)
        self.verbose = verbose
        self.started = False
        self.representative_samples = None
        self.max_iter = max_iter
        self.count = 0
        print('簇数:',self.n_clusters)
        
        
    def fit(self, x):    
        """
        实现过程
        @x:训练的数据集，参考sklearn，数据类型为DataFrame
        @: 返回聚类中心
        """
        #         dataframe.shape()
        # 返回形状，即几行几列的数组，如[2,3],shape[0]=rows,shape[1]=columns
        rows=x.shape[0]
        columns=x.shape[1]
        
        # （1）为每个聚类选择一个初始聚类中心；
        # 即随机生成n_clusters个中心
        # https://blog.csdn.net/yangwangnndd/article/details/106524093
        
        i_row = torch.randint(0,rows, (self.n_clusters,))
        i_points=x[i_row]
        self.centers=torch.tensor(i_points,dtype=torch.float)
        print('初始聚类中心:\n',i_points)
        iter=0
        while(True):
            iter++
            if(iter>self.max_iter):
                print('超过最大迭代次数')
                break
            # （2）将样本集按照最小距离原则分配到最邻近聚类；
            # 即遍历data
            labels = torch.empty((x.shape[0],)).long()
            dists = torch.empty((0, self.n_clusters))
            print('本轮的簇类中心是',self.centers)
            for i, sample in enumerate(x):
                # 计算距离
                # 注意torch计算需要类型转换为张量
                sample=torch.tensor(sample)
               # print(type(sample))
              #  print(type(self.centers))
                dist = torch.sum(torch.mul(sample - self.centers, sample - self.centers), (1))
                print('当前计算点%',i)
                print('和簇类中心集的距离向量:',dist)
                # 分配到最小索引
                # https://blog.csdn.net/sinat_37145472/article/details/94753866
                labels[i] = torch.argmin(dist)
                print('它离%d最近'%(labels[i]))
                dists = torch.cat([dists, dist.unsqueeze(0)], (0))
                print('更新距离矩阵',dists)
            # 最终labels更新
            self.labels = labels
            print('本轮最终的标签输出是',self.labels)
            # 
            if self.started:
                self.variation = torch.sum(self.dists - dists)
            ##
            self.dists = dists
            #
            self.started = True
            ##
        #    break
        #（3）使用每个聚类的样本均值更新聚类中心；
            # torch初始化向量
            # https://www.jianshu.com/p/d1a9916ccfe8
            
            # 簇类中心集是n_clusters X columns 的矩阵
            new_centers = torch.empty((self.n_clusters, columns))
            
            # 一共更新n_clusters个centers
            for i in range(self.n_clusters):
                # 找到该中心的周围的点的索引
                mask = self.labels == i
                # 找到他们
                cluster_samples = torch.tensor(x[mask])
                print(mask)
                print('属于该中心的点',cluster_samples)
                # 计算新一轮的队列中心
                new_centers[i] = torch.mean(cluster_samples, (0),dtype=torch.float)
                print('计算的新中心',new_centers[i])
                # 如果没有属于该中心的点，保持原状
                print(torch.isnan(new_centers[i]).int().sum()>0)
                if(torch.isnan(new_centers[i]).int().sum()>0):
                    new_centers[i]=self.centers[i]
            print('原中心',self.centers)
            print('新的中心',new_centers)
        #（4）重复步骤（2）、（3），直到聚类中心不再发生变化；
            if(torch.equal(new_centers, self.centers)):
                break
            else:
                self.centers = new_centers
        #（5）输出最终的聚类中心和 k 个簇划分（作图）；
        print('#############################')
        print('最终结果',self.centers)
        print('它们包含的点')
        for i in range(self.n_clusters):
            
        print('#############图像############(假设二维)')
        plt.scatter(x.values[:,0],x.values[:,1],c=self.labels,linewidth=linewidth)
        plt.scatter(self.centers[:,0], self.centers[:, 1], c='black',linewidth = 2, s=80, marker='o')
        
        return self.centers

# %%
centers = torch.empty((3, 2))
t=torch.tensor([1,1])
centers
# Out:
# tensor([[5.6052e-45, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00],
#         [4.2039e-45, 0.0000e+00]])

# %%
centers[1,:]=t
centers
# Out:
# tensor([[5.6052e-45, 0.0000e+00],
#         [1.0000e+00, 1.0000e+00],
#         [4.2039e-45, 0.0000e+00]])

# %%
test=My_KMeans(n_clusters=3)
# Out:
# 簇数: 3

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=5, centers=3, n_features=2,
                   random_state=0)
print(X)
print(y)
# Out:
# [[-1.08304078  3.25155659]
#  [ 0.87305123  4.71438583]
#  [ 1.9263585   4.15243012]
#  [ 2.81630525  1.01933868]
#  [ 2.19931109  2.35193717]]
# [2 0 0 1 1]

# %%
test.fit(X)
# Out:
# 初始聚类中心:
#  [[ 2.81630525  1.01933868]
#  [-1.08304078  3.25155659]
#  [ 2.81630525  1.01933868]]
# 本轮的簇类中心是 tensor([[ 2.8163,  1.0193],
#         [-1.0830,  3.2516],
#         [ 2.8163,  1.0193]])
# 当前计算点% 0
# 和簇类中心集的距离向量: tensor([2.0188e+01, 4.9427e-15, 2.0188e+01], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[2.0188e+01, 4.9427e-15, 2.0188e+01]], dtype=torch.float64)
# 当前计算点% 1
# 和簇类中心集的距离向量: tensor([17.4296,  5.9662, 17.4296], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[2.0188e+01, 4.9427e-15, 2.0188e+01],
#         [1.7430e+01, 5.9662e+00, 1.7430e+01]], dtype=torch.float64)
# 当前计算点% 2
# 和簇类中心集的距离向量: tensor([10.6083,  9.8681, 10.6083], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[2.0188e+01, 4.9427e-15, 2.0188e+01],
#         [1.7430e+01, 5.9662e+00, 1.7430e+01],
#         [1.0608e+01, 9.8681e+00, 1.0608e+01]], dtype=torch.float64)
# 当前计算点% 3
# 和簇类中心集的距离向量: tensor([9.9629e-15, 2.0188e+01, 9.9629e-15], dtype=torch.float64)
# 它离0最近
# 更新距离矩阵 tensor([[2.0188e+01, 4.9427e-15, 2.0188e+01],
#         [1.7430e+01, 5.9662e+00, 1.7430e+01],
#         [1.0608e+01, 9.8681e+00, 1.0608e+01],
#         [9.9629e-15, 2.0188e+01, 9.9629e-15]], dtype=torch.float64)
# 当前计算点% 4
# 和簇类中心集的距离向量: tensor([ 2.1565, 11.5831,  2.1565], dtype=torch.float64)
# 它离0最近
# 更新距离矩阵 tensor([[2.0188e+01, 4.9427e-15, 2.0188e+01],
#         [1.7430e+01, 5.9662e+00, 1.7430e+01],
#         [1.0608e+01, 9.8681e+00, 1.0608e+01],
#         [9.9629e-15, 2.0188e+01, 9.9629e-15],
#         [2.1565e+00, 1.1583e+01, 2.1565e+00]], dtype=torch.float64)
# 本轮最终的标签输出是 tensor([1, 1, 1, 0, 0])
# tensor([False, False, False,  True,  True])
# 属于该中心的点 tensor([[2.8163, 1.0193],
#         [2.1993, 2.3519]], dtype=torch.float64)
# 计算的新中心 tensor([2.5078, 1.6856])
# tensor(False)
# tensor([ True,  True,  True, False, False])
# 属于该中心的点 tensor([[-1.0830,  3.2516],
#         [ 0.8731,  4.7144],
#         [ 1.9264,  4.1524]], dtype=torch.float64)
# 计算的新中心 tensor([0.5721, 4.0395])
# tensor(False)
# tensor([False, False, False, False, False])
# 属于该中心的点 tensor([], size=(0, 2), dtype=torch.float64)
# 计算的新中心 tensor([nan, nan])
# tensor(True)
# 原中心 tensor([[ 2.8163,  1.0193],
#         [-1.0830,  3.2516],
#         [ 2.8163,  1.0193]])
# 新的中心 tensor([[2.5078, 1.6856],
#         [0.5721, 4.0395],
#         [2.8163, 1.0193]])
# 本轮的簇类中心是 tensor([[2.5078, 1.6856],
#         [0.5721, 4.0395],
#         [2.8163, 1.0193]])
# 当前计算点% 0
# 和簇类中心集的距离向量: tensor([15.3463,  3.3604, 20.1877], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[15.3463,  3.3604, 20.1877]], dtype=torch.float64)
# 当前计算点% 1
# 和簇类中心集的距离向量: tensor([11.8457,  0.5461, 17.4296], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[15.3463,  3.3604, 20.1877],
#         [11.8457,  0.5461, 17.4296]], dtype=torch.float64)
# 当前计算点% 2
# 和簇类中心集的距离向量: tensor([ 6.4231,  1.8467, 10.6083], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[15.3463,  3.3604, 20.1877],
#         [11.8457,  0.5461, 17.4296],
#         [ 6.4231,  1.8467, 10.6083]], dtype=torch.float64)
# 当前计算点% 3
# 和簇类中心集的距离向量: tensor([5.3913e-01, 1.4157e+01, 9.9629e-15], dtype=torch.float64)
# 它离2最近
# 更新距离矩阵 tensor([[1.5346e+01, 3.3604e+00, 2.0188e+01],
#         [1.1846e+01, 5.4609e-01, 1.7430e+01],
#         [6.4231e+00, 1.8467e+00, 1.0608e+01],
#         [5.3913e-01, 1.4157e+01, 9.9629e-15]], dtype=torch.float64)
# 当前计算点% 4
# 和簇类中心集的距离向量: tensor([0.5391, 5.4955, 2.1565], dtype=torch.float64)
# 它离0最近
# 更新距离矩阵 tensor([[1.5346e+01, 3.3604e+00, 2.0188e+01],
#         [1.1846e+01, 5.4609e-01, 1.7430e+01],
#         [6.4231e+00, 1.8467e+00, 1.0608e+01],
#         [5.3913e-01, 1.4157e+01, 9.9629e-15],
#         [5.3913e-01, 5.4955e+00, 2.1565e+00]], dtype=torch.float64)
# 本轮最终的标签输出是 tensor([1, 1, 1, 2, 0])
# tensor([False, False, False, False,  True])
# 属于该中心的点 tensor([[2.1993, 2.3519]], dtype=torch.float64)
# 计算的新中心 tensor([2.1993, 2.3519])
# tensor(False)
# tensor([ True,  True,  True, False, False])
# 属于该中心的点 tensor([[-1.0830,  3.2516],
#         [ 0.8731,  4.7144],
#         [ 1.9264,  4.1524]], dtype=torch.float64)
# 计算的新中心 tensor([0.5721, 4.0395])
# tensor(False)
# tensor([False, False, False,  True, False])
# 属于该中心的点 tensor([[2.8163, 1.0193]], dtype=torch.float64)
# 计算的新中心 tensor([2.8163, 1.0193])
# tensor(False)
# 原中心 tensor([[2.5078, 1.6856],
#         [0.5721, 4.0395],
#         [2.8163, 1.0193]])
# 新的中心 tensor([[2.1993, 2.3519],
#         [0.5721, 4.0395],
#         [2.8163, 1.0193]])
# 本轮的簇类中心是 tensor([[2.1993, 2.3519],
#         [0.5721, 4.0395],
#         [2.8163, 1.0193]])
# 当前计算点% 0
# 和簇类中心集的距离向量: tensor([11.5831,  3.3604, 20.1877], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[11.5831,  3.3604, 20.1877]], dtype=torch.float64)
# 当前计算点% 1
# 和簇类中心集的距离向量: tensor([ 7.3401,  0.5461, 17.4296], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[11.5831,  3.3604, 20.1877],
#         [ 7.3401,  0.5461, 17.4296]], dtype=torch.float64)
# 当前计算点% 2
# 和簇类中心集的距离向量: tensor([ 3.3163,  1.8467, 10.6083], dtype=torch.float64)
# 它离1最近
# 更新距离矩阵 tensor([[11.5831,  3.3604, 20.1877],
#         [ 7.3401,  0.5461, 17.4296],
#         [ 3.3163,  1.8467, 10.6083]], dtype=torch.float64)
# 当前计算点% 3
# 和簇类中心集的距离向量: tensor([2.1565e+00, 1.4157e+01, 9.9629e-15], dtype=torch.float64)
# 它离2最近
# 更新距离矩阵 tensor([[1.1583e+01, 3.3604e+00, 2.0188e+01],
#         [7.3401e+00, 5.4609e-01, 1.7430e+01],
#         [3.3163e+00, 1.8467e+00, 1.0608e+01],
#         [2.1565e+00, 1.4157e+01, 9.9629e-15]], dtype=torch.float64)
# 当前计算点% 4
# 和簇类中心集的距离向量: tensor([1.7956e-14, 5.4955e+00, 2.1565e+00], dtype=torch.float64)
# 它离0最近
# 更新距离矩阵 tensor([[1.1583e+01, 3.3604e+00, 2.0188e+01],
#         [7.3401e+00, 5.4609e-01, 1.7430e+01],
#         [3.3163e+00, 1.8467e+00, 1.0608e+01],
#         [2.1565e+00, 1.4157e+01, 9.9629e-15],
#         [1.7956e-14, 5.4955e+00, 2.1565e+00]], dtype=torch.float64)
# 本轮最终的标签输出是 tensor([1, 1, 1, 2, 0])
# tensor([False, False, False, False,  True])
# 属于该中心的点 tensor([[2.1993, 2.3519]], dtype=torch.float64)
# 计算的新中心 tensor([2.1993, 2.3519])
# tensor(False)
# tensor([ True,  True,  True, False, False])
# 属于该中心的点 tensor([[-1.0830,  3.2516],
#         [ 0.8731,  4.7144],
#         [ 1.9264,  4.1524]], dtype=torch.float64)
# 计算的新中心 tensor([0.5721, 4.0395])
# tensor(False)
# tensor([False, False, False,  True, False])
# 属于该中心的点 tensor([[2.8163, 1.0193]], dtype=torch.float64)
# 计算的新中心 tensor([2.8163, 1.0193])
# tensor(False)
# 原中心 tensor([[2.1993, 2.3519],
#         [0.5721, 4.0395],
#         [2.8163, 1.0193]])
# 新的中心 tensor([[2.1993, 2.3519],
#         [0.5721, 4.0395],
#         [2.8163, 1.0193]])
